# %% [markdown]
# # Introduction to pandas
#
# Take from one of the labs. Do the same as files_corpora, but save the info to a file. Also the length of sentences.

# %% [markdown]
#  # <mark>CONTINUE HERE</mark>
#
# Plan:
#
# 1. Do the same thing as files_copora, but output to pandas
#
# 2. Other ways of getting data (Fruhwald)
#
#
#
#
#  https://programminghistorian.org/en/lessons/corpus-analysis-with-spacy
#
#
#  Also also: put all the contents into one file.
#
#
#  MORE CONTINUE: do sentences and then len, set, fredist, lex div, etc. Do that also for the entire set of files, as aa single corpus.
#
#  https://bbengfort.github.io/2016/04/nltk-corpus-reader/
#
# https://www.linkedin.com/pulse/corpus-analysis-iii-python-juan-mart%C3%ADn-fern%C3%A1ndez-rowda/
#
# https://constellate.org/dashboard/tutorials/tokenize-text-files-with-nltk
#
# This as a way to get data and manipulate it: https://jofrhwld.github.io/teaching/courses/2022_lin517/lectures/data_processing/
